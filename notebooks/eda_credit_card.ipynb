# %%
# -----------------------------
# Imports & Setup
# -----------------------------
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import logging
from pathlib import Path
import sys
import warnings

warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", 50)

project_root = Path.cwd().resolve().parent 
sys.path.append(str(project_root))

from src.data.loader import CreditCardDataLoader
from src.data.cleaner import TransactionDataCleaner
from src.utils.io_utils import save_dataframe



logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
logger = logging.getLogger("EDA_Fraud")

# %%
# -----------------------------
# Helper Functions
# -----------------------------
def plot_count(df: pd.DataFrame, column: str, title: str, rotation: int = 0, save_path: str = None):
    plt.figure(figsize=(8,5))
    sns.countplot(x=column, data=df)
    plt.title(title)
    plt.xticks(rotation=rotation)
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
    plt.show()

def plot_hist(df: pd.DataFrame, column: str, bins: int = 50, kde: bool = True, title: str = None, save_path: str = None):
    plt.figure(figsize=(10,5))
    sns.histplot(df[column], bins=bins, kde=kde)
    if title:
        plt.title(title)
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
    plt.show()

def plot_box(df: pd.DataFrame, x: str, y: str, ylim_quantile: float = 0.95, title: str = None, save_path: str = None):
    plt.figure(figsize=(10,5))
    sns.boxplot(x=x, y=y, data=df)
    if ylim_quantile < 1.0:
        plt.ylim(0, df[y].quantile(ylim_quantile))
    if title:
        plt.title(title)
    if save_path:
        plt.savefig(save_path, bbox_inches='tight')
    plt.show()

# %%
try:
    raw_path = project_root / "data/raw/creditcard.csv"
    credit_loader = CreditCardDataLoader(raw_path)
    credit_df = credit_loader.load()
    logger.info(f"Credit card data shape: {credit_df.shape}")
    logger.info(f"Credit card data columns: {credit_df.columns.tolist()}")
except Exception as e:
    logger.error(f"Failed to load credit card data: {e}")
    raise
# Out:
# 2026-02-14 12:55:47,358 [INFO] Loaded file: C:\Users\amare\Documents\KAIM\week5-6\financial-fraud-detection\data\raw\creditcard.csv with shape (284807, 31)
# 2026-02-14 12:55:47,378 [INFO] Credit card dataset validation complete
# 2026-02-14 12:55:47,378 [INFO] Credit card data shape: (284807, 31)
# 2026-02-14 12:55:47,380 [INFO] Credit card data columns: ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']

# %%
credit_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
credit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
# -----------------------------
# Initial Data Report
# -----------------------------
cleaner = TransactionDataCleaner(credit_df)
logger.info("Initial Data Report:")
cleaner.report()
# Out:
# 2026-02-14 12:55:48,671 [INFO] Initial Data Report:
# 2026-02-14 12:55:48,677 [INFO] Dataset shape: (284807, 31)
# 2026-02-14 12:55:48,678 [INFO] Column data types:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object
# 2026-02-14 12:55:49,993 [INFO] Number of duplicate rows: 1081
# 2026-02-14 12:55:50,022 [INFO] Missing values per column:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# ...

# %%
# -----------------------------
# Data Cleaning
# -----------------------------
try:
    credit_df_clean = cleaner.clean(missing_strategy="fill_median")
    logger.info("Data cleaning completed.")
    logger.info("Post-cleaning report:")
    cleaner.report()
except Exception as e:
    logger.error(f"Data cleaning failed: {e}")
    raise
# Out:
# 2026-02-14 12:55:50,047 [INFO] Starting cleaning with strategy: fill_median
# 2026-02-14 12:55:51,915 [INFO] Removed 1081 duplicate rows
# 2026-02-14 12:55:51,947 [INFO] No missing values detected
# 2026-02-14 12:55:51,956 [INFO] Data cleaning completed.
# 2026-02-14 12:55:51,956 [INFO] Post-cleaning report:
# 2026-02-14 12:55:51,956 [INFO] Dataset shape: (283726, 31)
# 2026-02-14 12:55:51,961 [INFO] Column data types:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# ...

# %%
# -----------------------------
# Exploratory Data Analysis (EDA)
# -----------------------------

# Class distribution
plot_count(credit_df_clean, column="Class", title="Class Distribution (Legit vs Fraud)")
# Out:
# 2026-02-14 12:55:53,841 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-02-14 12:55:54,091 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
# Amount distribution and outliers
plot_box(credit_df_clean, x="Class", y="Amount", title="Transaction Amount by Class", ylim_quantile=0.95)
plot_hist(credit_df_clean, column="Amount", bins=50, title="Transaction Amount Distribution")
# Out:
# 2026-02-14 12:55:54,907 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-02-14 12:55:55,187 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
# Time distribution
plt.figure(figsize=(10,5))
sns.histplot(credit_df_clean, x='Time', hue='Class', multiple='stack', bins=50)
plt.title("Time Distribution of Transactions by Class")
plt.show()

# %%
# Optional: Top transactions by amount
top_amounts = credit_df_clean.nlargest(10, 'Amount')
logger.info(f"Top 10 transactions by amount:\n{top_amounts[['Time','Amount','Class']]}")
# Out:
# 2026-02-14 12:55:57,981 [INFO] Top 10 transactions by amount:
#             Time    Amount  Class
# 274771  166198.0  25691.16      0
# 58465    48401.0  19656.53      0
# 151296   95286.0  18910.00      0
# 46841    42951.0  12910.93      0
# 54018    46253.0  11898.09      0
# 169457  119713.0  11789.84      0
# 284249  172273.0  10199.44      0
# 227921  145283.0  10000.00      0
# 74699    55709.0   8790.26      0
# 245474  152763.0   8787.00      0

# %%
# -----------------------------
# Class Distribution Analysis
# -----------------------------
class_count = credit_df_clean['Class'].value_counts()
class_pct = credit_df_clean['Class'].value_counts(normalize=True) * 100
logger.info(f"Class distribution:\n{class_count}")
logger.info(f"Class percentage:\n{class_pct}")
# Out:
# 2026-02-14 12:55:58,000 [INFO] Class distribution:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64
# 2026-02-14 12:55:58,004 [INFO] Class percentage:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %%
# -----------------------------
# Save Cleaned Data
# -----------------------------
try:
    processed_path = project_root / "data/processed/credit_data_cleaned.csv"
    save_dataframe(credit_df_clean, str(processed_path))
    logger.info(f"Cleaned credit card data saved to {processed_path}")
except Exception as e:
    logger.error(f"Failed to save cleaned data: {e}")
    raise
# Out:
# 2026-02-14 12:56:19,241 [INFO] [IO] Data saved successfully to C:\Users\amare\Documents\KAIM\week5-6\financial-fraud-detection\data\processed\credit_data_cleaned.csv (csv)
# 2026-02-14 12:56:19,241 [INFO] Cleaned credit card data saved to C:\Users\amare\Documents\KAIM\week5-6\financial-fraud-detection\data\processed\credit_data_cleaned.csv

# %%
# -----------------------------
# End of Notebook
# -----------------------------
logger.info("Credit Card EDA Notebook completed successfully.")
# Out:
# 2026-02-14 12:56:19,267 [INFO] Credit Card EDA Notebook completed successfully.
